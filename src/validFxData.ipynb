# %% [markdown]
# # areacello/sftof validation - compare v1.1.9 and v1.1.10
# <div style="text-align: right">
# <p>
#     <img src="https://pcmdi.github.io/assets/PCMDI/199x65px-PCMDI-Logo-Text-rectangle.png"
#          width="91"
#          height="30"
#          class="fixed-height-image"
#          style="margin-right: 20px"
#          title="Program for Climate Model Diagnosis and Intercomparison"
#          alt="Program for Climate Model Diagnosis and Intercomparison"
#     >&nbsp;
#     <img src="https://pcmdi.github.io/assets/LLNL/212px-LLNLiconPMS286-WHITEBACKGROUND.png"
#          width="30"
#          height="30"
#          class="fixed-height-image"
#          style="margin-right: 20px"
#          title="Lawrence Livermore National Laboratory"
#          alt="Lawrence Livermore National Laboratory"
#     >&nbsp;
#     <img src="https://pcmdi.github.io/assets/DOE/459x127px-DOE-Logo_Color_TextOnly.png"
#          width="108"
#          height="30"
#          class="fixed-height-image"
#          style="margin-right: 20px"
#          title="United States Department of Energy"
#          alt="United States Department of Energy"
#     >
# </p>
# </div>

# %% [markdown]
# # **Summary**
#
# This file pulls validates the `areacello` and `sftof` v1.1.9 and v1.1.10 datasets.
#
# **Authors:**
#
# Paul J. Durack ([durack1](https://github.com/durack1); [PCMDI](https://pcmdi.llnl.gov/), [Lawrence Livermore National Laboratory](https://www.llnl.gov/))
#
# **Notes:**
#
# PJD 31 Jul 2025 - initiated<br>
# PJD 31 Jul 2025 - data updates `v20250731` seem to checkout ok, but minor differences in `areacello` exist<br>
#
# **TODO:**
#
# **Links:**

# %% [markdown]
# ### imports

# %%
# %%time
import os
import xcdat as xc
import xarray as xr
# Out:
# CPU times: user 3.62 s, sys: 529 ms, total: 4.15 s
# Wall time: 4.68 s

# %% [markdown]
# ### list data and plot

# %% [markdown]
# ### areacella

# %%
a119fp = os.path.join(
    "..", "SST_1-1-10", "areacello_input4MIPs_SSTsAndSeaIce_CMIP_PCMDI-AMIP-1-1-9_gn.nc"
)
fh119 = xc.open_dataset(a119fp, decode_times=False)

# %%
fh119["areacello"].plot()
fh119["areacello"].sum()
# areacello = fh119.spatial.get_weights(axis="Y")
# areacello, _ = xr.broadcast(areacello, fh119.lon)
# areacello = areacello/720
# areacello.sum()
# Out:
# <xarray.DataArray 'areacello' ()> Size: 4B
# array(5.101e+14, dtype=float32)

# %%
a1110fp = os.path.join(
    "..",
    "input4MIPs/CMIP7/CMIP/PCMDI/PCMDI-AMIP-1-1-10/ocean/fx/areacello/gn/v20250729",
    "areacello_input4MIPs_SSTsAndSeaIce_CMIP_PCMDI-AMIP-1-1-10_gn.nc",
)
fh1110 = xc.open_dataset(a1110fp, decode_times=False)

# %%
fh1110["areacello"].plot()
fh1110["areacello"].sum()
# Out:
# <xarray.DataArray 'areacello' ()> Size: 4B
# array(3.67272e+17, dtype=float32)

# %%
diff = fh1110["areacello"] - fh119["areacello"]
diff.plot()

# %%
a1110fp = os.path.join(
    "..",
    "input4MIPs/CMIP7/CMIP/PCMDI/PCMDI-AMIP-1-1-10/ocean/fx/areacello/gn/v20250731",
    "areacello_input4MIPs_SSTsAndSeaIce_CMIP_PCMDI-AMIP-1-1-10_gn.nc",
)
fh1110 = xc.open_dataset(a1110fp, decode_times=False)

# %%
fh1110["areacello"].plot()
fh1110["areacello"].sum()
# Out:
# <xarray.DataArray 'areacello' ()> Size: 4B
# array(5.101e+14, dtype=float32)

# %%
diff = fh1110["areacello"] - fh119["areacello"]
diff.plot()

# %% [markdown]
# ### sftof

# %%
s119fp = os.path.join(
    "..", "SST_1-1-10", "sftof_input4MIPs_SSTsAndSeaIce_CMIP_PCMDI-AMIP-1-1-9_gn.nc"
)
fh119 = xc.open_dataset(s119fp, decode_times=False)

# %%
fh119["sftof"].plot()

# %%
s1110fp = os.path.join(
    "..",
    "input4MIPs/CMIP7/CMIP/PCMDI/PCMDI-AMIP-1-1-10/ocean/fx/sftof/gn/v20250729",
    "sftof_input4MIPs_SSTsAndSeaIce_CMIP_PCMDI-AMIP-1-1-10_gn.nc",
)
fh1110 = xc.open_dataset(s1110fp, decode_times=False)

# %%
fh1110["sftof"].plot()

# %%
diff = fh1110["sftof"] - fh119["sftof"]
diff.plot()
